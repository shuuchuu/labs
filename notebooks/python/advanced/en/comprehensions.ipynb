# %% [markdown]
# # Comprehensions
#
# In these practical exercises, you will have to reimplement the various iterations provided using comprehensions.

# %% [markdown]
# ## Simple Comprehension

# %%
d = {"a": [1, 2, 3], "b": [1, 2, 3, 4, 5]}

lengths = {}
for k, v in d.items():
    lengths[k] = len(v)
print(lengths)

# %%
# Your code here

# %% [markdown]
# ### Solution

# %%
lengths = {k: len(v) for k, v in d.items()}
print(lengths)

# %% [markdown]
# ## Nested Iteration Comprehensions

# %%
a_list = [1, 2, 3]
b_list = ["a", "b", "c"]
cartesian_product = []
for a in a_list:
    for b in b_list:
        cartesian_product.append((a, b))
print(cartesian_product)

# %%
# Your code here

# %% [markdown]
# ### Solution

# %%
cartesian_product = [(a, b) for a in a_list for b in b_list]
print(cartesian_product)

# %% [markdown]
# ## File

# %%
with open("sample_data/README.md", encoding="utf8") as fh:
    total = 0
    for line in fh:
        total += len(line)
print(total)

# %%
# Your code here

# %% [markdown]
# ### Solution

# %%
with open("sample_data/README.md", encoding="utf8") as fh:
    total = sum(len(line) for line in fh)
print(total)

# %% [markdown]
# ## Multiple Iteration Comprehensions with Conditions

# %%
a_list = [1, 2, 3]
b_list = ["a", "b", "c"]
cartesian_product = []
for i, a in enumerate(a_list):
    if i % 2 == 0:
        for j, b in enumerate(b_list):
            if j % 2 == 0:
                cartesian_product.append((a, b))
print(cartesian_product)

# %%
# Your code here

# %% [markdown]
# ### Solution

# %%
cartesian_product = [
    (a, b)
    for i, a in enumerate(a_list)
    if i % 2 == 0
    for j, b in enumerate(b_list)
    if j % 2 == 0
]
print(cartesian_product)
