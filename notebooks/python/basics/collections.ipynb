# %% [markdown]
# # Collections

# %% [markdown]
# ## Jours de la semaine
#
# Constituez une liste `semaine` contenant les 7 jours de la semaine sour la forme de chaînes de caractères&nbsp;: `"lundi"`, `"mardi"`, etc.

# %%
# Votre code ici

# %% [markdown]
# Créez deux variables, `dernier_jour_1` et `dernier_jour_2` et affectez leur le dernier jour de la liste `semaine`, de deux manières différentes.

# %%
# Votre code ici

# %% [markdown]
# À partir la liste `semaine`, récupérez les 5 premiers jours dans la variable `jours_ouvres` et les 2 jours du week-end dans la variable `weekend`. Utilisez pour cela l'indiçage.

# %%
# Votre code ici

# %% [markdown]
# Affectez les mêmes valeurs aux variables `jours_ouvres_2` et `weekend_2` en utilisant un autre indiçage.

# %%
# Votre code ici

# %% [markdown]
# Affectez les jours de la semaine inversés à la variable `semaine_inversee` en utilisant une tranche.

# %%
# Votre code ici

# %% [markdown]
# ### Solution

# %%
semaine = ["lundi", "mardi", "mercredi", "jeudi", "vendredi", "samedi",
           "dimanche"]

# Première question
dernier_jour_1 = semaine[6]
dernier_jour_2 = semaine[-1]
print(f"Dernier jour : {dernier_jour_1} {dernier_jour_2}")

# Deuxième question
jours_ouvres = semaine[:5]
weekend = semaine[5:]
print(f"Jours ouvrés : {jours_ouvres}, weekend : {weekend}")

# Troisième question
jours_ouvres_2 = semaine[:-2]
weekend_2 = semaine[-2:]
print(f"Jours ouvrés 2 : {jours_ouvres_2}, weekend : {weekend_2}")

# Dernière question
semaine_inversee = semaine[::-1]
print(f"Semaine inversée : {semaine_inversee}")

# %% [markdown]
# ## Saisons
#
# Prévoyez ce que renvoient les instructions suivantes, puis vérifiez-le dans l'interpréteur&nbsp;:
#
# - `saisons[2]`
# - `saisons[1][0]`
# - `saisons[1:2]`
# - `saisons[:][1]`. Comment expliquez-vous ce dernier résultat ?

# %%
hiver = ["decembre", "janvier", "fevrier"]
printemps = ["mars", "avril", "mai"]
ete = ["juin", "juillet", "aout"]
automne = ["septembre", "octobre", "novembre"]

saisons = [hiver, printemps, ete, automne]

# %% [markdown]
# ### Solution

# %%
hiver = ["decembre", "janvier", "fevrier"]
printemps = ["mars", "avril", "mai"]
ete = ["juin", "juillet", "aout"]
automne = ["septembre", "octobre", "novembre"]

saisons = [hiver, printemps, ete, automne]

print(saisons[2])
print(saisons[1][0])
print(saisons[1:2])
print(saisons[:][1])
# Explication du dernier point : prendre une tranche complète renvoie une copie
# de la liste, cela retourne donc le même élément que si l'on écrivait
# saisons[1] (et donc la liste de la deuxième saison, ["mars", "avril", "mai"])

# %% [markdown]
# ## Table de multiplication par 9
#
# Affichez la table de multiplication par $9$ (de $9 \times 1$ à $9 \times 10$) en une seule commande avec les instructions [`range`](https://docs.python.org/fr/3/library/functions.html#func-range) et [`list`](https://docs.python.org/fr/3/library/functions.html#func-list).

# %%
# Votre code ici

# %% [markdown]
# ### Solution

# %%
print(list(range(9, 91, 9)))

# %% [markdown]
# ## Nombres pairs
#
# Répondez à la question suivante en une seule commande. Combien y a-t-il de nombres pairs dans l'intervalle `[2, 10000]` inclus ?

# %%
# Votre code ici

# %% [markdown]
# ### Solution

# %%
print(len(range(2, 10_001, 2)))

# %% [markdown]
# ## Manipulation d'ensembles
#
# Étant donné les ensembles de caractéristiques de langages de programmation suivants (vous pourrez consulter [la page d'aide](https://docs.python.org/3/library/stdtypes.html#set-types-set-frozenset) des ensembles pendant l'exercice) :
#
# - Trouvez les caractéristiques communes au JavaScript et au Python
# - Trouvez les caractéristiques exclusives du Java par rapport au Python
# - Quel est l'ensemble complet des caractéristiques ?
# - Quelles sont les caractéristiques exclusives du Python par rapport à tous les autres langages ?

# %%
js = {"typage dynamique", "interprété", "web natif", "orienté prototype"}
python = {"typage dynamique", "interprété", "calcul scientifique", "orienté objet"}
java = {"compilé", "orienté objet", "typage statique"}

langages = [js, python, java]

# %%
# Votre code ici

# %% [markdown]
# ### Solution

# %%
print("Caractéristiques communes au JS et au Python :",
      js & python)
print("Caractéristiques exclusives du Java par rapport au Python :",
      java - python)
print("Ensemble complet des caractéristiques :",
      set.union(*langages))
print("Caractéristiques exclusives du Python par rapport aux autres :",
      python.difference(js, java))

# %% [markdown]
# ## Manipulation de tuples
#
# Repartez de deux exercices sur les listes de votre choix et reproduisez les en créant des `tuple`.
#
# Que se passe-t-il si vous essayez de modifier un de ces tuples ?

# %%
# Votre code ici

# %% [markdown]
# *Votre réponse ici*

# %% [markdown]
# ### Solution

# %%
mon_tuple = (1, 2, 3)
mon_tuple[1] = 5

# %% [markdown]
# ## Manipulation de dictionnaires
#
# On souhaite ré-exprimer l'exercice des saisons cette fois avec des dictionnaires.
#
# - Créez un dictionnaire `saisons` qui contient 4 entrées, chacune étant la liste définie à l'exercice précédent.
#
# - Comment accéder au deuxième mois de l'hiver ?
#
# - Comment vérifier avec un appel Python si `ete` est une clef présente dans le dictionnaire `saisons` ?

# %%
# Votre code ici

# %% [markdown]
# ### Solution

# %%
saisons = {"hiver": ["decembre", "janvier", "fevrier"],
           "printemps": ["mars", "avril", "mai"],
           "ete": ["juin", "juillet", "aout"],
           "automne": ["septembre", "octobre", "novembre"]}

print(saisons["hiver"][1])
print("ete" in saisons)
