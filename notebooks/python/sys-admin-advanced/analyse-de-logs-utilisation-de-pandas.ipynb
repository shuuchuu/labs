# %% [markdown]
# # Analyse de logs & utilisation de pandas

# %%
# @title À exécuter : mise en place de l'environnement
# !rm -rf sample_data
# !curl -sSL https://install.python-poetry.org | python - --version 1.6.1
path = %env PATH
poetry_path = "/root/.local/bin"
if poetry_path not in path:
  path = f"{poetry_path}:{path}"
  # %set_env PATH $path
# !poetry config repositories.testpypi https://test.pypi.org/legacy/
# !poetry config virtualenvs.create false

# %% [markdown]
# ## Récupération des données

# %%
# !wget https://raw.githubusercontent.com/m09/dataset-nginx-log/main/access-small.log

# %% [markdown]
# ## Instructions

# %% [markdown]
# - Créer une regex qui sépare les différents éléments de chaque entrée de log
# - Ingérer les logs séparés dans une `DataFrame` pandas
# - Créer une CLI qui permet de créer un log filtré en fonction de la date

# %% [markdown]
# ## Solution

# %% [markdown]
# La solution est disponible sur [GitHub](https://github.com/m09/tp-nginx).
